# %% [markdown]
# #### This notebook is created as submission for Assignment 02, Analytics for Unstructured Data
# Submitted by: Ruchi Sharma

# %% [markdown]
# #### Building a Crowdsourced Recommender System
#
# High level description: The objective of this assignment is to create the building blocks of a
# crowdsourced recommender system. It should accept user inputs in the form of desired attributes of a
# product and come up with 3 recommendations.
#
# Obtain reviews of craft beers from beeradvocate.com.

# %%
'''

import sys
sys.executable

# !/opt/anaconda3/bin/python -m pip install spacy
# !/opt/anaconda3/bin/python -m pip install nltk
# !/opt/anaconda3/bin/python -m pip install vaderSentiment
# !/opt/anaconda3/bin/python -m spacy download en_core_web_lg

'''
# Out:
# '\n\nimport sys\nsys.executable\n\n!/opt/anaconda3/bin/python -m pip install spacy\n!/opt/anaconda3/bin/python -m pip install nltk\n!/opt/anaconda3/bin/python -m pip install vaderSentiment\n!/opt/anaconda3/bin/python -m spacy download en_core_web_lg\n\n'

# %%
import requests
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import spacy 
import numpy as np
import string
import vaderSentiment

from bs4 import BeautifulSoup
from lxml import html
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set( stopwords.words('english'))

# %matplotlib inline

# %% [markdown]
# ##### Task A: Loading the scraped dataset

# %%
import pandas as pd
data = pd.read_csv("beer_reviews.csv")
data.head()
# Out:
#                   product_name  \
# 0  Kentucky Brunch Brand Stout
# 1  Kentucky Brunch Brand Stout
# 2  Kentucky Brunch Brand Stout
# 3  Kentucky Brunch Brand Stout
# 4  Kentucky Brunch Brand Stout
#
#                                       product_review  user_rating
# 0  I didnt think i was going to give it a perfect...         5.00
# 1  So I just read a review that called the legend...         3.79
# 2  2021 vintage, bottle #79\n\nHoly. Fucking. Shi...         4.64
# 3  Celebrating my buddy @Rug with his 1,000th bee...         4.27
# 4  Thick and syrupy pour, mocha head. Aroma is bo...         4.79

# %%
data.groupby(['product_name']).count()
# Out:
#                                product_review  user_rating
# product_name
# 18 Hours From Brooklyn                     13           13
# 25th Anniversary Ale                        5            5
# 26th Anniversary Imperial IPA              20           20
# 31 Pumpkin Spiced Lager                    18           18
# 312 Urban Wheat                            18           18
# ...                                       ...          ...
# Yellow                                      6            6
# Yellow Bus                                  7            7
# Zenne Y Frontera                            6            6
# Zombie Dust                                21           21
# §ucaba                                     15           15
#
# [567 rows x 2 columns]

# %%
# text preprocessing

data = data.dropna()
data['cleaned_review'] = data['product_review'].apply(lambda x :x.translate(str.maketrans('', '', string.punctuation)))
data['cleaned_review'] = data['cleaned_review'].apply(lambda x :x.lower())

data['cleaned_review'] = data['cleaned_review'].apply(word_tokenize).apply(set).apply(list)

def remove_stopwords(s):
    return [w for w in s if not w in stop_words] 
    
data['cleaned_review'] =  data['cleaned_review'].apply(remove_stopwords)

# %%
all_words = []
for i in range(len(data)):
    all_words+=data['cleaned_review'][i]
from nltk import FreqDist
word_freq = nltk.FreqDist(all_words)

# %%
word_freq.most_common()
# Out:
# [('head', 2882),
#  ('taste', 2206),
#  ('beer', 2089),
#  ('pours', 1534),
#  ('carbonation', 1457),
#  ('good', 1400),
#  ('sweet', 1383),
#  ('lacing', 1337),
#  ('overall', 1301),
#  ('finish', 1294),
#  ('nose', 1292),
#  ('one', 1257),
#  ('body', 1257),
#  ('aroma', 1251),
#  ('like', 1248),
#  ('light', 1216),
#  ('dark', 1187),
#  ('nice', 1172),
#  ('medium', 1151),
#  ('mouthfeel', 1151),
#  ('white', 1123),
#  ('notes', 1100),
#  ('color', 1072),
#  ('chocolate', 1071),
#  ('well', 1052),
#  ('glass', 1044),
#  ('flavor', 998),
#  ('malt', 995),
#  ('bit', 949),
#  ('black', 943),
#  ('feel', 928),
#  ('smooth', 925),
#  ('poured', 920),
#  ('bottle', 920),
#  ('vanilla', 906),
#  ('thick', 884),
#  ('really', 827),
#  ('bitterness', 819),
#  ('little', 811),
#  ('smell', 810),
#  ('brown', 807),
#  ('orange', 805),
#  ('caramel', 788),
#  ('great', 787),
#  ('creamy', 782),
#  ('bourbon', 777),
#  ('fruit', 768),
#  ('flavors', 726),
#  ('full', 713),
#  ('hops', 690),
#  ('barrel', 686),
#  ('citrus', 685),
#  ('’', 684),
#  ('coffee', 658),
#  ('much', 653),
#  ('dry', 652),
#  ('sweetness', 644),
#  ('hazy', 637),
#  ('stout', 633),
#  ('slightly', 618),
#  ('bitter', 603),
#  ('hop', 593),
#  ('retention', 567),
#  ('big', 561),
#  ('oak', 547),
#  ('bodied', 547),
#  ('thin', 541),
#  ('moderate', 525),
#  ('quite', 520),
#  ('alcohol', 517),
#  ('rich', 515),
#  ('abv', 505),
#  ('still', 502),
#  ('finger', 495),
#  ('would', 488),
#  ('clear', 481),
#  ('pour', 478),
#  ('balanced', 475),
#  ('malts', 471),
#  ('palate', 470),
#  ('style', 465),
#  ('soft', 461),
#  ('almost', 458),
#  ('tropical', 454),
#  ('hint', 453),
#  ('strong', 452),
#  ('slight', 450),
#  ('pretty', 449),
#  ('get', 448),
#  ('best', 439),
#  ('foam', 432),
#  ('touch', 419),
#  ('mango', 419),
#  ('also', 417),
#  ('smells', 416),
#  ('back', 416),
#  ('golden', 415),
#  ('pineapple', 411),
#  ('beers', 409),
#  ('grapefruit', 400),
#  ('roasted', 399),
#  ('excellent', 398),
#  ('drink', 397),
#  ('yellow', 396),
#  ('mouth', 394),
#  ('even', 394),
#  ('way', 391),
#  ('quickly', 387),
#  ('tan', 381),
#  ('aromas', 379),
#  ('definitely', 379),
#  ('appearance', 378),
#  ('end', 377),
#  ('follows', 376),
#  ('deep', 373),
#  ('ipa', 372),
#  ('look', 369),
#  ('front', 367),
#  ('earthy', 366),
#  ('heavy', 363),
#  ('first', 362),
#  ('mild', 358),
#  ('boozy', 356),
#  ('oz', 354),
#  ('fresh', 351),
#  ('time', 351),
#  ('juicy', 351),
#  ('brew', 349),
#  ('finishes', 342),
#  ('bread', 335),
#  ('amber', 330),
#  ('leaves', 329),
#  ('balance', 328),
#  ('sugar', 328),
#  ('solid', 327),
#  ('tastes', 325),
#  ('malty', 325),
#  ('canned', 323),
#  ('around', 322),
#  ('sticky', 322),
#  ('toffee', 318),
#  ('complex', 313),
#  ('character', 311),
#  ('better', 310),
#  ('coconut', 309),
#  ('toasted', 307),
#  ('fruity', 307),
#  ('lots', 304),
#  ('im', 303),
#  ('easy', 302),
#  ('small', 298),
#  ('peach', 292),
#  ('gold', 291),
#  ('lot', 284),
#  ('floral', 284),
#  ('think', 282),
#  ('top', 282),
#  ('hints', 281),
#  ('molasses', 280),
#  ('along', 280),
#  ('could', 278),
#  ('spicy', 277),
#  ('long', 277),
#  ('cinnamon', 277),
#  ('two', 276),
#  ('spice', 273),
#  ('pine', 271),
#  ('ring', 270),
#  ('profile', 269),
#  ('opaque', 268),
#  ('sip', 267),
#  ('bright', 267),
#  ('l', 267),
#  ('lingering', 266),
#  ('juice', 266),
#  ('high', 265),
#  ('delicious', 265),
#  ('lemon', 265),
#  ('super', 263),
#  ('fruits', 262),
#  ('maybe', 261),
#  ('bready', 261),
#  ('f', 261),
#  ('cap', 261),
#  ('crisp', 261),
#  ('though', 258),
#  ('try', 257),
#  ('12', 256),
#  ('clean', 255),
#  ('pale', 255),
#  ('drinking', 253),
#  ('another', 253),
#  ('note', 252),
#  ('right', 244),
#  ('ive', 243),
#  ('wine', 243),
#  ('lace', 243),
#  ('side', 242),
#  ('decent', 240),
#  ('fantastic', 239),
#  ('low', 239),
#  ('aftertaste', 236),
#  ('subtle', 235),
#  ('expected', 233),
#  ('tasty', 232),
#  ('amount', 230),
#  ('base', 230),
#  ('dank', 230),
#  ('drinkable', 230),
#  ('theres', 228),
#  ('house', 228),
#  ('maple', 227),
#  ('fluffy', 227),
#  ('tulip', 226),
#  ('perfect', 225),
#  ('looks', 224),
#  ('hoppy', 223),
#  ('dont', 222),
#  ('colored', 221),
#  ('snifter', 220),
#  ('tart', 219),
#  ('love', 218),
#  ('huge', 218),
#  ('nicely', 218),
#  ('warming', 216),
#  ('bite', 216),
#  ('sure', 216),
#  ('herbal', 216),
#  ('fingers', 214),
#  ('tree', 214),
#  ('cocoa', 212),
#  ('yet', 212),
#  ('something', 209),
#  ('see', 209),
#  ('less', 208),
#  ('fine', 208),
#  ('enough', 208),
#  ('old', 208),
#  ('pint', 207),
#  ('without', 206),
#  ('comes', 206),
#  ('fairly', 206),
#  ('minimal', 205),
#  ('fades', 205),
#  ('forward', 204),
#  ('ale', 204),
#  ('tasting', 203),
#  ('worth', 203),
#  ('imperial', 202),
#  ('aged', 201),
#  ('leaving', 200),
#  ('booze', 200),
#  ('got', 199),
#  ('beautiful', 198),
#  ('frothy', 197),
#  ('tongue', 196),
#  ('warms', 194),
#  ('enjoyable', 193),
#  ('heat', 192),
#  ('cloudy', 192),
#  ('date', 192),
#  ('honey', 191),
#  ('cream', 190),
#  ('lightly', 190),
#  ('going', 189),
#  ('dense', 189),
#  ('offwhite', 189),
#  ('ever', 187),
#  ('cherry', 187),
#  ('tangerine', 186),
#  ('melon', 185),
#  ('foamy', 185),
#  ('roast', 184),
#  ('presence', 184),
#  ('green', 184),
#  ('favorite', 184),
#  ('doesnt', 183),
#  ('makes', 183),
#  ('brings', 182),
#  ('grassy', 182),
#  ('thats', 180),
#  ('bad', 180),
#  ('say', 176),
#  ('ba', 176),
#  ('years', 175),
#  ('16oz', 175),
#  ('sour', 175),
#  ('done', 174),
#  ('2', 174),
#  ('brewery', 174),
#  ('syrup', 173),
#  ('nothing', 172),
#  ('seems', 171),
#  ('faint', 171),
#  ('middle', 170),
#  ('2021', 169),
#  ('slowly', 169),
#  ('inch', 169),
#  ('pleasant', 168),
#  ('red', 168),
#  ('mostly', 168),
#  ('lighter', 168),
#  ('amazing', 167),
#  ('copper', 167),
#  ('yeast', 167),
#  ('bubbles', 166),
#  ('average', 166),
#  ('left', 166),
#  ('half', 165),
#  ('oily', 165),
#  ('looking', 165),
#  ('served', 163),
#  ('rather', 163),
#  ('present', 163),
#  ('enjoy', 161),
#  ('blend', 161),
#  ('find', 161),
#  ('funk', 160),
#  ('16', 160),
#  ('milk', 159),
#  ('similar', 159),
#  ('probably', 158),
#  ('tap', 158),
#  ('new', 158),
#  ('interesting', 158),
#  ('never', 157),
#  ('pepper', 157),
#  ('plenty', 157),
#  ('vintage', 156),
#  ('roasty', 156),
#  ('review', 155),
#  ('stouts', 155),
#  ('2022', 155),
#  ('char', 154),
#  ('12oz', 153),
#  ('made', 150),
#  ('warm', 150),
#  ('somewhat', 150),
#  ('refreshing', 150),
#  ('wonderful', 149),
#  ('many', 148),
#  ('hard', 148),
#  ('wood', 148),
#  ('take', 148),
#  ('away', 148),
#  ('id', 147),
#  ('go', 146),
#  ('slick', 146),
#  ('dated', 146),
#  ('might', 146),
#  ('thing', 145),
#  ('complexity', 144),
#  ('oktoberfest', 144),
#  ('syrupy', 143),
#  ('make', 142),
#  ('come', 142),
#  ('day', 141),
#  ('chewy', 141),
#  ('followed', 140),
#  ('3', 140),
#  ('papaya', 140),
#  ('burnt', 139),
#  ('outstanding', 139),
#  ('ripe', 139),
#  ('know', 139),
#  ('apricot', 139),
#  ('mix', 138),
#  ('apple', 138),
#  ('every', 137),
#  ('want', 136),
#  ('feels', 136),
#  ('far', 136),
#  ('behind', 136),
#  ('grain', 135),
#  ('wheat', 135),
#  ('grass', 135),
#  ('actually', 134),
#  ('gentle', 134),
#  ('mocha', 134),
#  ('whiskey', 134),
#  ('goes', 133),
#  ('version', 133),
#  ('nearly', 133),
#  ('bottled', 133),
#  ('carb', 132),
#  ('barrels', 132),
#  ('always', 132),
#  ('getting', 132),
#  ('hot', 131),
#  ('lingers', 130),
#  ('together', 130),
#  ('overly', 130),
#  ('absolutely', 129),
#  ('incredible', 128),
#  ('liquid', 128),
#  ('different', 127),
#  ('texture', 127),
#  ('classic', 127),
#  ('sharp', 127),
#  ('enjoyed', 126),
#  ('everything', 126),
#  ('collar', 126),
#  ('noticeable', 126),
#  ('sweeter', 125),
#  ('4', 125),
#  ('wow', 125),
#  ('short', 124),
#  ('grape', 124),
#  ('rye', 124),
#  ('world', 123),
#  ('warmth', 123),
#  ('quality', 123),
#  ('stone', 123),
#  ('burn', 122),
#  ('drank', 122),
#  ('brewing', 122),
#  ('year', 122),
#  ('consumed', 121),
#  ('viscous', 121),
#  ('unique', 121),
#  ('dissipates', 120),
#  ('peppery', 120),
#  ('moderately', 120),
#  ('perhaps', 120),
#  ('carbonated', 120),
#  ('expect', 120),
#  ('certainly', 119),
#  ('silky', 119),
#  ('haze', 119),
#  ('leather', 118),
#  ('throughout', 118),
#  ('background', 118),
#  ('drinks', 118),
#  ('guava', 118),
#  ('kind', 117),
#  ('zest', 117),
#  ('real', 116),
#  ('stuff', 116),
#  ('raisin', 116),
#  ('peel', 116),
#  ('level', 115),
#  ('fudge', 115),
#  ('last', 115),
#  ('intense', 114),
#  ('1', 114),
#  ('marzen', 114),
#  ('anything', 112),
#  ('2020', 112),
#  ('khaki', 112),
#  ('isnt', 112),
#  ('tobacco', 111),
#  ('licorice', 111),
#  ('lager', 111),
#  ('5', 110),
#  ('may', 110),
#  ('however', 109),
#  ('swallow', 109),
#  ('depth', 109),
#  ('oil', 109),
#  ('candied', 109),
#  ('glad', 108),
#  ('give', 107),
#  ('resin', 107),
#  ('point', 107),
#  ('murky', 107),
#  ('toasty', 106),
#  ('coming', 106),
#  ('extremely', 106),
#  ('experience', 105),
#  ('easily', 105),
#  ('rind', 105),
#  ('straw', 105),
#  ('perfectly', 104),
#  ('purchased', 104),
#  ('double', 104),
#  ('large', 104),
#  ('banana', 104),
#  ('pitch', 103),
#  ('start', 103),
#  ('spices', 103),
#  ('piney', 103),
#  ('found', 102),
#  ('“', 102),
#  ('cant', 102),
#  ('dried', 102),
#  ('edge', 102),
#  ('typical', 102),
#  ('jet', 101),
#  ('layer', 101),
#  ('buy', 100),
#  ('lime', 100),
#  ('nutty', 100),
#  ('three', 99),
#  ('hits', 99),
#  ('edges', 99),
#  ('starts', 99),
#  ('hidden', 99),
#  ('thought', 98),
#  ('surprisingly', 98),
#  ('raisins', 98),
#  ('ipas', 98),
#  ('let', 98),
#  ('close', 97),
#  ('bold', 97),
#  ('neipa', 97),
#  ('near', 97),
#  ('tartness', 97),
#  ('”', 96),
#  ('initial', 96),
#  ('sipper', 96),
#  ('fridge', 96),
#  ('impressive', 96),
#  ('acidity', 96),
#  ('cheers', 95),
#  ('picking', 95),
#  ('backbone', 95),
#  ('least', 95),
#  ('rating', 95),
#  ('bottom', 95),
#  ('lovely', 94),
#  ('across', 94),
#  ('part', 94),
#  ('especially', 94),
#  ('awesome', 93),
#  ('tried', 92),
#  ('linger', 91),
#  ('citrusy', 91),
#  ('although', 91),
#  ('tasted', 90),
#  ('didnt', 90),
#  ('grains', 90),
#  ('gets', 90),
#  ('highly', 90),
#  ('oaky', 90),
#  ('settles', 90),
#  ('pumpkin', 90),
#  ('cloying', 89),
#  ('loads', 89),
#  ('tons', 89),
#  ('ml', 89),
#  ('thanks', 88),
#  ('mixed', 88),
#  ('resinous', 88),
#  ('pack', 88),
#  ('bought', 88),
#  ('release', 88),
#  ('gives', 88),
#  ('charred', 87),
#  ('label', 87),
#  ('cans', 87),
#  ('given', 86),
#  ('lasting', 86),
#  ('barleywine', 86),
#  ('bomb', 85),
#  ('else', 84),
#  ('candy', 84),
#  ('fan', 84),
#  ('hit', 84),
#  ('upfront', 84),
#  ('american', 84),
#  ('things', 83),
#  ('whole', 83),
#  ('finally', 83),
#  ('velvety', 83),
#  ('class', 83),
#  ('aging', 83),
#  ('funky', 83),
#  ('flavorful', 83),
#  ('6', 83),
#  ('darker', 83),
#  ('completely', 82),
#  ('incredibly', 82),
#  ('single', 82),
#  ('cherries', 82),
#  ('adds', 82),
#  ('raspberry', 82),
#  ('aggressive', 81),
#  ('toast', 81),
#  ('coating', 81),
#  ('lower', 81),
#  ('soapy', 81),
#  ('festbier', 81),
#  ('opens', 80),
#  ('figs', 80),
#  ('cold', 80),
#  ('woody', 80),
#  ('dryness', 80),
#  ('passionfruit', 80),
#  ('others', 80),
#  ('truly', 79),
#  ('espresso', 79),
#  ('shows', 79),
#  ('drying', 78),
#  ('marshmallow', 78),
#  ('pick', 78),
#  ('takes', 78),
#  ('next', 78),
#  ('compared', 78),
#  ('days', 78),
#  ('prominent', 78),
#  ('bubbly', 78),
#  ('damn', 77),
#  ('decadent', 77),
#  ('making', 77),
#  ('reminds', 77),
#  ('temp', 77),
#  ('grainy', 77),
#  ('hue', 77),
#  ('smoke', 77),
#  ('dessert', 77),
#  ('german', 77),
#  ('price', 77),
#  ('late', 76),
#  ('standard', 76),
#  ('open', 76),
#  ('15', 76),
#  ('mug', 75),
#  ('pouring', 75),
#  ('oh', 75),
#  ('keep', 74),
#  ('mildly', 74),
#  ('prefer', 74),
#  ('massive', 74),
#  ('ounce', 74),
#  ('fizzy', 74),
#  ('plum', 73),
#  ('sugary', 73),
#  ('scent', 73),
#  ('drinkability', 73),
#  ('dipa', 73),
#  ('trying', 73),
#  ('th', 73),
#  ('surface', 73),
#  ('series', 73),
#  ('plus', 73),
#  ('tall', 73),
#  ('10', 72),
#  ('film', 72),
#  ('2019', 72),
#  ('sort', 72),
#  ('need', 72),
#  ('effervescence', 72),
#  ('beige', 72),
#  ('legs', 71),
#  ('addition', 71),
#  ('picked', 71),
#  ('cake', 71),
#  ('wish', 71),
#  ('guys', 71),
#  ('pillowy', 71),
#  ('wet', 71),
#  ('towards', 71),
#  ('stronger', 70),
#  ('seem', 70),
#  ('use', 70),
#  ('zesty', 70),
#  ('ago', 70),
#  ('used', 69),
#  ('exactly', 69),
#  ('straight', 69),
#  ('punch', 69),
#  ('pastry', 69),
#  ('expecting', 69),
#  ('treat', 69),
#  ('months', 69),
#  ('temperature', 68),
#  ('since', 68),
#  ('batch', 68),
#  ('either', 68),
#  ('example', 68),
#  ('visible', 68),
#  ('ruby', 68),
#  ('age', 68),
#  ('held', 68),
#  ('milky', 68),
#  ('immediately', 67),
#  ('second', 67),
#  ('regular', 67),
#  ('said', 67),
#  ('motor', 67),
#  ('line', 67),
#  ('ok', 67),
#  ('mahogany', 67),
#  ('pith', 66),
#  ('midpalate', 65),
#  ('mind', 65),
#  ('coast', 65),
#  ('clarity', 65),
#  ('recedes', 64),
#  ('citra', 64),
#  ('subdued', 64),
#  ('king', 64),
#  ('425', 64),
#  ('acidic', 64),
#  ('quarter', 64),
#  ('belgian', 64),
#  ('delicate', 64),
#  ('earthiness', 63),
#  ('came', 63),
#  ('west', 63),
#  ('cantaloupe', 63),
#  ('relatively', 63),
#  ('higher', 63),
#  ('combination', 63),
#  ('pairs', 62),
#  ('hype', 62),
#  ('sense', 62),
#  ('upon', 62),
#  ('bean', 62),
#  ('overpowering', 62),
#  ('extra', 62),
#  ('pear', 62),
#  ('fig', 62),
#  ('spiciness', 62),
#  ('tad', 62),
#  ('robust', 61),
#  ('barley', 61),
#  ('add', 61),
#  ('works', 61),
#  ('highlights', 61),
#  ('booziness', 61),
#  ('rum', 61),
#  ('resulting', 60),
#  ('tones', 60),
#  ('otherwise', 60),
#  ('must', 60),
#  ('liked', 60),
#  ('night', 60),
#  ('bar', 60),
#  ('elements', 60),
#  ('brewed', 60),
#  ('rated', 59),
#  ('share', 59),
#  ('put', 59),
#  ('draft', 59),
#  ('variant', 59),
#  ('despite', 59),
#  ('store', 59),
#  ('residual', 59),
#  ('cracker', 59),
#  ('2018', 59),
#  ('spotty', 59),
#  ('due', 59),
#  ('topped', 58),
#  ('dankness', 58),
#  ('special', 58),
#  ('thickness', 58),
#  ('usual', 58),
#  ('overripe', 58),
#  ('degrees', 58),
#  ('brewers', 58),
#  ('offering', 58),
#  ('modest', 58),
#  ('guess', 57),
#  ('simple', 57),
#  ('750ml', 57),
#  ('type', 57),
#  ('layers', 57),
#  ('ample', 57),
#  ('tiny', 57),
#  ('cola', 57),
#  ('oranges', 57),
#  ('dominate', 57),
#  ('forms', 57),
#  ('lively', 57),
#  ('wild', 57),
#  ('fun', 57),
#  ('pilsner', 57),
#  ('ton', 56),
#  ('added', 56),
#  ('past', 56),
#  ('tangy', 56),
#  ('rocky', 56),
#  ('mellow', 56),
#  ('wonderfully', 56),
#  ('hay', 56),
#  ('ill', 56),
#  ('round', 55),
#  ('room', 55),
#  ('minutes', 55),
#  ('impression', 55),
#  ('biscuit', 55),
#  ('hill', 55),
#  ('crust', 55),
#  ('underneath', 54),
#  ('45', 54),
#  ('leads', 54),
#  ('true', 54),
#  ('work', 54),
#  ('fuller', 54),
#  ('muted', 54),
#  ('clove', 54),
#  ('finishing', 54),
#  ('mediumbodied', 54),
#  ('adjuncts', 53),
#  ('cool', 53),
#  ('reviewed', 53),
#  ('hope', 53),
#  ('usually', 53),
#  ('8', 53),
#  ('faded', 53),
#  ('creaminess', 53),
#  ('blueberry', 53),
#  ('14', 53),
#  ('doughy', 53),
#  ('center', 53),
#  ('sides', 53),
#  ('pie', 52),
#  ('grapes', 52),
#  ('coats', 52),
#  ('turbid', 52),
#  ('dissipated', 52),
#  ('feeling', 52),
#  ('reddish', 52),
#  ('cut', 52),
#  ('flavour', 52),
#  ('berry', 52),
#  ('hazelnut', 52),
#  ('dough', 52),
#  ('ales', 52),
#  ('stamped', 52),
#  ('bittersweet', 51),
#  ('barely', 51),
#  ('firm', 51),
#  ('today', 51),
#  ('rings', 51),
#  ('peaches', 51),
#  ('mediumfull', 51),
#  ('apparent', 51),
#  ('srm', 51),
#  ('course', 50),
#  ('overwhelming', 50),
#  ('happy', 50),
#  ('absolute', 50),
#  ('courtesy', 50),
#  ('slow', 50),
#  ('berries', 50),
#  ('julius', 50),
#  ('couple', 50),
#  ('original', 50),
#  ('crystal', 50),
#  ('instead', 50),
#  ('strawberry', 50),
#  ('considering', 50),
#  ('nuts', 50),
#  ('offers', 49),
#  ('form', 49),
#  ('zero', 49),
#  ('pithy', 49),
#  ('often', 49),
#  ('treehouse', 49),
#  ('home', 49),
#  ('sampled', 49),
#  ('fullbodied', 49),
#  ('features', 49),
#  ('rounded', 49),
#  ('mediumlight', 49),
#  ('case', 48),
#  ('teku', 48),
#  ('becomes', 48),
#  ('port', 48),
#  ('toward', 48),
#  ('rest', 48),
#  ('–', 48),
#  ('capped', 48),
#  ('semisweet', 48),
#  ('surprised', 48),
#  ('bottles', 48),
#  ('spot', 48),
#  ('cellar', 48),
#  ('box', 48),
#  ('butter', 47),
#  ('simply', 47),
#  ('shared', 47),
#  ('initially', 47),
#  ('prickly', 47),
#  ('pop', 47),
#  ('took', 47),
#  ('times', 47),
#  ('bottling', 47),
#  ('restrained', 47),
#  ('musty', 47),
#  ('quick', 47),
#  ('fair', 47),
#  ('yes', 47),
#  ('beautifully', 47),
#  ('fall', 47),
#  ('somehow', 47),
#  ('weeks', 47),
#  ('nutmeg', 47),
#  ('porter', 47),
#  ('extreme', 47),
#  ('tea', 47),
#  ('throat', 46),
#  ('pure', 46),
#  ('man', 46),
#  ('early', 46),
#  ('water', 46),
#  ('adding', 46),
#  ('goodness', 46),
#  ('week', 46),
#  ('seen', 46),
#  ('offerings', 46),
#  ('additional', 46),
#  ('thinner', 46),
#  ('pink', 46),
#  ('effervescent', 46),
#  ('bring', 45),
#  ('wouldnt', 45),
#  ('undertones', 45),
#  ('excited', 45),
#  ('dominant', 45),
#  ('wrong', 45),
#  ('yeasty', 45),
#  ('several', 45),
#  ('distinct', 45),
#  ('via', 45),
#  ('pleasantly', 45),
#  ('dose', 45),
#  ('heavier', 44),
#  ('remains', 44),
#  ('fruitiness', 44),
#  ('kick', 44),
#  ('aromatic', 44),
#  ('honeydew', 44),
#  ('astringent', 44),
#  ('traditional', 44),
#  ('show', 44),
#  ('13', 44),
#  ('wasnt', 44),
#  ('bakers', 44),
#  ('colour', 44),
#  ('pronounced', 44),
#  ('says', 43),
#  ('likely', 43),
#  ('flat', 43),
#  ('esters', 43),
#  ('20', 43),
#  ('brews', 43),
#  ('nuttiness', 43),
#  ('seek', 43),
#  ('bba', 43),
#  ('100', 43),
#  ('7', 43),
#  ('honestly', 43),
#  ('vinous', 43),
#  ('fl', 43),
#  ('none', 43),
#  ('dollars', 43),
#  ('score', 42),
#  ('continues', 42),
#  ('opinion', 42),
#  ('leave', 42),
#  ('skin', 42),
#  ('smelled', 42),
#  ('craft', 42),
#  ('received', 42),
#  ('tell', 42),
#  ('clearly', 42),
#  ('later', 42),
#  ('sips', 41),
#  ('opened', 41),
#  ('able', 41),
#  ('underlying', 41),
#  ('final', 41),
#  ('local', 41),
#  ('serving', 41),
#  ('believe', 41),
#  ('smoky', 41),
#  ('translucent', 41),
#  ('saison', 41),
#  ('watery', 41),
#  ('pickedup', 41),
#  ('went', 40),
#  ('become', 40),
#  ('based', 40),
#  ('within', 40),
#  ('provides', 40),
#  ('brownie', 40),
#  ('keeps', 40),
#  ('call', 40),
#  ('strength', 40),
#  ('sticks', 40),
#  ('ones', 40),
#  ('friend', 40),
#  ('lasts', 40),
#  ('wait', 40),
#  ('creamsicle', 40),
#  ('375', 40),
#  ('onefinger', 40),
#  ('bubblegum', 40),
#  ('recommend', 40),
#  ('giving', 40),
#  ('rising', 40),
#  ('peanut', 40),
#  ('ice', 39),
#  ('dates', 39),
#  ('caramelized', 39),
#  ('fact', 39),
#  ('chance', 39),
#  ...]

# %% [markdown]
# From the above word frequency distribution, we can list out the top attributes or features associated with beer.
#
# Noting the following list of words assocaited with beer: carbonation, sweet, aroma, light, dark, medium, mouthfeel,
# color, chocolate, malt, vanilla, thick, smell, brown, orange,
# caramel, creamy, bourbon, fruit, hops, barrel , bitter, hop,
# tropical

# %% [markdown]
# ##### Task B: Assume that a customer, who will be using this recommender system, has specified 3 attributes in a product.
#
# E.g., one website describes multiple attributes of beer:
# https://www.dummies.com/food-drink/drinks/beer/beer-for-dummies-cheat-sheet/
#
# 1. Aggressive (Boldly assertive aroma and/or taste)
# 2. Balanced: Malt and hops in similar proportions; equal representation of malt sweetness and
# hop bitterness in the flavor — especially at the finish
# 3. Complex: Multidimensional; many flavors and sensations on the palate
# 4. Crisp: Highly carbonated; effervescent
# 5. Fruity: Flavors reminiscent of various fruits or Hoppy: Herbal, earthy, spicy, or citric aromas and flavors of hops or Malty: Grainy, caramel-like; can be sweet or dry
# 6. Robust: Rich and full-bodied
#
# Use the above attributes as examples only, for a word frequency analysis of beer reviews is a better way to find important attributes in the actual data.
#
# Assume that a customer has specified three attributes of the product as being important to him or her.

# %% [markdown]
# ###### For this experiment, let's consider dark, carbonation and creamy as the three attributes entered by the user.

# %% [markdown]
# ##### Task C: Perform a similarity analysis using the 3 attributes specified by the customer and the reviews.

# %%
import spacy
import en_core_web_lg
nlp = en_core_web_lg.load()

# %%
def join_words(comment):   
    """Joins the tokenized words to a sentence"""
    return " ".join(comment) 

data['joined_review'] = data['cleaned_review'].map(join_words)

# %%
# Calculate similarity with pre-processing functions

def calculate_similarity(comment):
    """Compute similarity score"""
    base = nlp(comment)
    compare = nlp(input_attributes)
    return base.similarity(compare)

# %%
input_list = ['dark', 'carbonation', 'creamy']
input_attributes =  " ".join(input_list)
data['similarity'] = data['joined_review'].map(calculate_similarity)
# Out:
# /var/folders/4b/v0kblg653q71bft9rhct3dvh0000gn/T/ipykernel_2944/1061434268.py:7: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   return base.similarity(compare)

# %%
data.head(10)
# Out:
#                   product_name  \
# 0  Kentucky Brunch Brand Stout
# 1  Kentucky Brunch Brand Stout
# 2  Kentucky Brunch Brand Stout
# 3  Kentucky Brunch Brand Stout
# 4  Kentucky Brunch Brand Stout
# 5  Kentucky Brunch Brand Stout
# 6  Kentucky Brunch Brand Stout
# 7  Kentucky Brunch Brand Stout
# 8  Kentucky Brunch Brand Stout
# 9  Kentucky Brunch Brand Stout
#
#                                       product_review  user_rating  \
# 0  I didnt think i was going to give it a perfect...         5.00
# 1  So I just read a review that called the legend...         3.79
# 2  2021 vintage, bottle #79\n\nHoly. Fucking. Shi...         4.64
# 3  Celebrating my buddy @Rug with his 1,000th bee...         4.27
# 4  Thick and syrupy pour, mocha head. Aroma is bo...         4.79
# 5  Had a big share and this was by far the best s...         5.00
# 6  Look - fantastic black and thick with a great ...         4.73
# 7  Initial nose is beautiful maple! The taste is ...         4.96
# 8  A: Nightfall in appearance that presents a cla...         4.23
# 9                       Thanks for the pour Azuelke!         4.64
#
#                                       cleaned_review  \
# 0  [real, pancakes, maple, grabs, familiar, taste...
# 1  [’, pretentious, heavy, ”, breaking, nose, jud...
# 2  [end, morbid, 1000, whole, signature, unless, ...
# 3  [rug, someone, tasted, flavor, feels, chocolat...
# 4  [chocolate, heavy, expectations, carbonation, ...
# 5                     [far, big, share, best, stout]
# 6  [fantastic, black, look, creamy, maple, great,...
# 7  [chocolate, knock, nose, high, beer, viscosity...
# 8  [aids, placed, ’, lingers, peripheral, set, ce...
# 9                            [pour, thanks, azuelke]
#
#                                        joined_review  similarity
# 0  real pancakes maple grabs familiar taste give ...    0.581676
# 1  ’ pretentious heavy ” breaking nose judge beer...    0.606326
# 2  end morbid 1000 whole signature unless im nose...    0.670074
# 3  rug someone tasted flavor feels chocolate ’ bu...    0.659777
# 4  chocolate heavy expectations carbonation lived...    0.796936
# 5                           far big share best stout    0.323280
# 6  fantastic black look creamy maple great head s...    0.747402
# 7  chocolate knock nose high beer viscosity sligh...    0.697868
# 8  aids placed ’ lingers peripheral set centering...    0.721594
# 9                                pour thanks azuelke    0.241991

# %%
top300_reviews = data.sort_values(by='similarity', ascending=False)[0:300]
top300_reviews
# Out:
#                             product_name  \
# 2386                      KBS - Hazelnut
# 3092  Barrel Aged Exhausted Parent Stout
# 3093  Barrel Aged Exhausted Parent Stout
# 1891         Damon (Bourbon Barrel Aged)
# 3320                    Rocky Road Stout
# ...                                  ...
# 941              Black Tuesday - Reserve
# 4482                        Old Rasputin
# 3442                      Electric Skies
# 2369          Project Find The Limit #10
# 4185                 Samuel Adams Jack-O
#
#                                          product_review  user_rating  \
# 2386  The deepest of dark brown liquid swirls into y...         4.93
# 3092  A - Pours a very dark brown with a thin tan he...         4.30
# 3093  Pours a dark brown color with a minimal head t...         4.43
# 1891  Bottle: Poured a pitch-black color stout with ...         4.50
# 3320  Rocky Road Stout has a thin, fizzing-away beig...         4.46
# ...                                                 ...          ...
# 941   Very good head production, considering the sky...         4.56
# 4482  Black as used motor oil. Thick consistency. St...         4.72
# 3442  Canned on 5/28/22; consumed on 6/21/22\n\nPour...         4.29
# 2369  Canned on 06-09-22.\n\nA - Opaque pineapple or...         4.41
# 4185  Copper to light amber in color with excellent ...         3.35
#
#                                          cleaned_review  \
# 2386  [luscious, flavor, liquid, chocolate, variant,...
# 3092  [chocolate, solid, black, carbonation, heat, c...
# 3093  [color, minimal, black, creamy, dark, sweet, h...
# 1891  [chocolate, large, color, barrelaged, solid, n...
# 3320  [flavor, milk, chocolate, road, high, sweetnes...
# ...                                                 ...
# 941   [double, molasses, nose, oak, foam, sweet, che...
# 4482  [flavor, chocolate, notes, smoky, black, beers...
# 3442  [end, textures, consumed, frothy, blanc, repre...
# 2369  [fantasic, lots, color, citrus, spicy, silky, ...
# 4185  [thirds, ’, two, pie, around, color, carbonati...
#
#                                           joined_review  similarity
# 2386  luscious flavor liquid chocolate variant evolu...    0.851299
# 3092  chocolate solid black carbonation heat creamy ...    0.851100
# 3093  color minimal black creamy dark sweet head smo...    0.850226
# 1891  chocolate large color barrelaged solid notes b...    0.849690
# 3320  flavor milk chocolate road high sweetness silk...    0.849404
# ...                                                 ...         ...
# 941   double molasses nose oak foam sweet chest quic...    0.800929
# 4482  flavor chocolate notes smoky black beers dark ...    0.800866
# 3442  end textures consumed frothy blanc representat...    0.800863
# 2369  fantasic lots color citrus spicy silky 060922 ...    0.800842
# 4185  thirds ’ two pie around color carbonation mode...    0.800713
#
# [300 rows x 6 columns]

# %% [markdown]
# ##### Task D: For every review, perform a sentiment analysis (using VADER).

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
def sentiment_analyzer_scores(sentence):
    
    """Generate seniment score"""
    scores = analyser.polarity_scores(sentence)
    return scores['compound']

top300_reviews['sentiment'] = top300_reviews['product_review'].map(sentiment_analyzer_scores)

# %%
top300_reviews_sentiment = top300_reviews.sort_values(by='sentiment', ascending=False)

# %%
top300_reviews_sentiment
# Out:
#                                            product_name  \
# 3800  Speedway Stout - Madagascar Vanilla & Ceylon A...
# 3710                      Banana Colada Melted Sno Cone
# 3342                              Big Bad Baptist Naked
# 2842                                 Even More Nobility
# 3361              Barrel Aged Fully Loaded French Toast
# ...                                                 ...
# 4537                                   Blue Hen Pilsner
# 3406                         LAX To JFK : In The Clouds
# 3040                                       Blender King
# 3894                        Double Fractal Penrose Tile
# 4709                                     Atomic Torpedo
#
#                                          product_review  user_rating  \
# 3800  Poured from the can into a teku style glass.\n...         4.44
# 3710  A: Pours an opaque murky thick sludgy milky pa...         4.26
# 3342  From the 22 oz bottle in a snifter. This excep...         4.37
# 2842  A: Pours an opaque yet still clear thick visco...         4.22
# 3361  A: Pours an opaque yet still clear thick visco...         4.36
# ...                                                 ...          ...
# 4537  Blue Hen Pilsner has a thick, off-white head, ...         4.50
# 3406  Poured from a can dated 10/27/21\nThick cloudy...         4.17
# 3040  Murky dark orange with two fingers of yellowed...         4.08
# 3894  Pours an opaque grapefruit with thin lacing an...         4.09
# 4709  568 ml can, from Vinmonopolet, Nettbutikken. A...         3.76
#
#                                          cleaned_review  \
# 3800  [kick, grandeur, swirling, looking, nose, cake...
# 3710  [reduces, two, minimal, beer, spring, evokes, ...
# 3342  [wafting, two, heavy, raspberry, nose, beer, t...
# 2842  [reduces, two, beer, toasted, pretty, lacing, ...
# 3361  [reduces, two, minimal, beer, toasted, lacing,...
# ...                                                 ...
# 4537  [hop, flavor, bubbly, pilsner, cracker, minima...
# 3406  [tart, overly, dissipating, ’, heavy, thicker,...
# 3040  [easter, two, tasty, mango, nose, fingers, car...
# 3894  [hop, flavor, nose, resin, carbonation, lacing...
# 4709  [82, base, deep, malts, large, malty, 568, vin...
#
#                                           joined_review  similarity  sentiment
# 3800  kick grandeur swirling looking nose cake finge...    0.828255     0.9975
# 3710  reduces two minimal beer spring evokes lacing ...    0.814653     0.9959
# 3342  wafting two heavy raspberry nose beer turn lac...    0.804232     0.9957
# 2842  reduces two beer toasted pretty lacing lingeri...    0.818179     0.9949
# 3361  reduces two minimal beer toasted lacing oak co...    0.817935     0.9935
# ...                                                 ...         ...        ...
# 4537  hop flavor bubbly pilsner cracker minimal hen ...    0.814212    -0.4019
# 3406  tart overly dissipating ’ heavy thicker stone ...    0.815495    -0.4168
# 3040  easter two tasty mango nose fingers carbonatio...    0.828534    -0.4767
# 3894  hop flavor nose resin carbonation lacing tropi...    0.815912    -0.4939
# 4709  82 base deep malts large malty 568 vinmonopole...    0.801400    -0.5712
#
# [300 rows x 7 columns]

# %% [markdown]
# ##### Task E: Create an evaluation score for each beer that uses both similarity and sentiment scores.
# E.g. total score  = average of (similarity score + sentiment score) or a multiplicative model.
#
# ##### Now recommend 3 products to the customer.

# %%
top300_reviews_combined = top300_reviews.groupby('product_name')[['similarity','sentiment']].mean()
top300_reviews_combined['recommend'] = top300_reviews_combined['similarity']+top300_reviews_combined['sentiment']

# %%
top300_reviews_combined.sort_values(by='recommend', ascending=False)[0:3]
# Out:
#                                      similarity  sentiment  recommend
# product_name
# Mexican Brunch                         0.825498     0.9911   1.816598
# Plead The 5th - Bourbon Barrel-Aged    0.827077     0.9884   1.815477
# Endless                                0.837786     0.9757   1.813486

# %%
data['sentiment'] = data['product_review'].map(sentiment_analyzer_scores)

# %%
reviews_df_combined = data.groupby('product_name')[['similarity','sentiment', 'user_rating']].mean()
reviews_df_combined['recommend'] = reviews_df_combined['similarity']+reviews_df_combined['sentiment']

# %%
reviews_df_combined.sort_values(by = 'user_rating', ascending = False)[0:3]
# Out:
#                                          similarity  sentiment  user_rating  \
# product_name
# The Adjunct Trail - Bourbon Barrel-Aged    0.662782    0.81260     4.930000
# Triple Shot - House Blend                  0.803807    0.98780     4.840000
# Twice the Daily Serving: Raspberry         0.639894    0.75505     4.833333
#
#                                          recommend
# product_name
# The Adjunct Trail - Bourbon Barrel-Aged   1.475382
# Triple Shot - House Blend                 1.791607
# Twice the Daily Serving: Raspberry        1.394944

# %% [markdown]
# ##### Thus, we get the final recommnedations on the basis of similarity combined with sentiment as "The Adjunct Trail - Bourbon Barrel-Aged", "Triple Shot - House Blend", "Twice the Daily Serving: Raspberry" for the three selected attributes.
